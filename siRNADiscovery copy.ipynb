# %%
import stellargraph as StellarGraph
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import scipy
import scipy.sparse
import scipy.sparse.linalg
import matplotlib.pyplot as plt
import re, json

from stellargraph.mapper import HinSAGENodeGenerator
from stellargraph.layer import HinSAGE
from tensorflow.keras import layers, Model, optimizers, callbacks
from sklearn.metrics import roc_auc_score
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"


import utils  # Features calculation

params = json.load(open("siRNA_param.json", "r"))


score_PCC = []
score_SPCC = []
score_mse = []
score_auc = []


for n in range(3):

    """

    Read File

    """

    # Read file
    data_train = pd.read_csv("siRNA_split_datasets/split" + str(n) + "/train.csv")
    data_dev = pd.read_csv("siRNA_split_datasets/split" + str(n) + "/dev.csv")
    data_test = pd.read_csv("siRNA_split_datasets/split" + str(n) + "/test.csv")

    # Substitue U to T
    data_train["siRNA_seq"] = data_train["siRNA_seq"].replace("U", "T", regex=True)
    data_dev["siRNA_seq"] = data_dev["siRNA_seq"].replace("U", "T", regex=True)
    data_test["siRNA_seq"] = data_test["siRNA_seq"].replace("U", "T", regex=True)

    # Concat data
    data = pd.concat([data_train, data_dev, data_test], axis=0)

    """

    Feature processing

    """

    # one-hot
    ## siRNA
    sirna_onehot = [
        utils.obtain_one_hot_feature_for_one_sequence_1(seq, params["sirna_length"])
        for seq in data["siRNA_seq"]
    ]
    sirna_onehot = pd.DataFrame(sirna_onehot, index=list(data["siRNA"]))

    ## mRNA
    mrna_onehot_temp = data.loc[:, ["mRNA", "mRNA_seq"]]
    mrna_onehot_temp = mrna_onehot_temp.drop_duplicates(subset="mRNA")

    mrna_onehot = [
        utils.obtain_one_hot_feature_for_one_sequence_1(seq, params["max_mrna_len"])
        for seq in mrna_onehot_temp["mRNA_seq"]
    ]
    mrna_onehot = pd.DataFrame(mrna_onehot, index=list(mrna_onehot_temp["mRNA"]))

    # Positional encoding
    trans_table = str.maketrans("ATCG", "TAGC")
    data["match_pos"] = [
        seq[::-1].upper().translate(trans_table) for seq in data["siRNA_seq"]
    ]
    data["match_pos"] = data.apply(
        lambda row: row["mRNA_seq"].index(row["match_pos"]), axis=1
    )

    sirna_pos_encoding = [
        utils.get_pos_embedding_sequence(num, params["sirna_length"], params["dmodel"])
        for num in data["match_pos"]
    ]
    sirna_pos_encoding = pd.DataFrame(sirna_pos_encoding, index=list(data["siRNA"]))

    # Thermodynamics
    sirna_thermo_feat = [
        utils.cal_thermo_feature(seq.replace("T", "U")) for seq in data["siRNA_seq"]
    ]

    sirna_thermo_feat = pd.DataFrame(sirna_thermo_feat).reset_index(drop=True)

    sirna_thermo_feat = pd.concat(
        [
            data["siRNA"].reset_index(drop=True),
            data["mRNA"].reset_index(drop=True),
            sirna_thermo_feat,
        ],
        axis=1,
    )

    sirna_thermo_feat["index"] = (
        sirna_thermo_feat["siRNA"] + "_" + sirna_thermo_feat["mRNA"]
    )
    sirna_thermo_feat = sirna_thermo_feat.set_index("index").drop(
        columns=["siRNA", "mRNA"]
    )

    # Co-fold features
    con_feat = pd.read_csv(
        "siRNA_split_preprocess/con_matrix.txt", header=None, index_col=0
    )

    con_feat = con_feat.reindex(sirna_thermo_feat.index)

    # sel-fold features
    ## siRNA
    sirna_sfold_feat = pd.read_csv(
        "siRNA_split_preprocess/self_siRNA_matrix.txt", header=None, index_col=0
    )

    sirna_sfold_feat = sirna_sfold_feat.reindex(sirna_onehot.index)

    ## mRNA
    mrna_sfold_feat = pd.read_csv(
        "siRNA_split_preprocess/self_mRNA_matrix.txt", header=None, index_col=0
    )

    mrna_sfold_feat = mrna_sfold_feat.reindex(mrna_onehot.index)

    # AGO2
    ## siRNA-AGO2
    sirna_ago = pd.read_csv("RNA_AGO2/siRNA_AGO2.csv", index_col=0)

    sirna_ago = sirna_ago.reindex(sirna_onehot.index)

    ## mRNA-AGO2
    mrna_ago = pd.read_csv("RNA_AGO2/mRNA_AGO2.csv", index_col=0)

    mrna_ago = mrna_ago.reindex(mrna_onehot.index)

    # GC percentage
    ## siRNA
    sirna_GC = [utils.countGC(seq) for seq in data["siRNA_seq"]]
    sirna_GC = pd.DataFrame(sirna_GC, index=list(data["siRNA"]))

    ## mRNA
    mrna_GC = [utils.countGC(seq) for seq in mrna_onehot_temp["mRNA_seq"]]
    mrna_GC = pd.DataFrame(mrna_GC, index=list(mrna_onehot_temp["mRNA"]))

    # k-mers
    sirna_1_mer = pd.DataFrame([utils.single_freq(seq) for seq in data["siRNA_seq"]])
    sirna_2_mers = pd.DataFrame([utils.double_freq(seq) for seq in data["siRNA_seq"]])
    sirna_3_mers = pd.DataFrame([utils.triple_freq(seq) for seq in data["siRNA_seq"]])
    sirna_4_mers = pd.DataFrame(
        [utils.quadruple_freq(seq) for seq in data["siRNA_seq"]]
    )
    sirna_5_mers = pd.DataFrame(
        [utils.quintuple_freq(seq) for seq in data["siRNA_seq"]]
    )

    sirna_k_mers = pd.concat(
        [sirna_1_mer, sirna_2_mers, sirna_3_mers, sirna_4_mers, sirna_5_mers], axis=1
    )
    sirna_k_mers.index = data["siRNA"]

    # siRNA rules codes
    sirna_pos_scores = [utils.rules_scores(seq) for seq in data["siRNA_seq"]]
    sirna_pos_scores = pd.DataFrame(sirna_pos_scores, index=list(data["siRNA"]))

    """

    The features of GNN nodes

    """

    # siRNA nodes
    sirna_pd = pd.concat(
        [
            sirna_onehot,
            sirna_sfold_feat,
            sirna_ago,
            sirna_GC,
            sirna_k_mers,
            sirna_pos_scores,
        ],
        axis=1,
    )

    # mRNA nodes
    mrna_pd = pd.concat([mrna_onehot, mrna_sfold_feat, mrna_ago, mrna_GC], axis=1)

    # edges
    source = data["siRNA"] + "_" + data["mRNA"]
    target_siRNA = data["siRNA"]
    target_mRNA = data["mRNA"]

    all_my_edges1 = pd.DataFrame({"source": source, "target": target_siRNA})
    all_my_edges2 = pd.DataFrame({"source": source, "target": target_mRNA})

    all_my_edges = pd.concat([all_my_edges1, all_my_edges2], ignore_index=True, axis=0)

    # interactive nodes
    sirna_pos_encoding.index = sirna_thermo_feat.index

    interaction_pd = pd.concat(
        [sirna_thermo_feat, con_feat, sirna_pos_encoding], axis=1
    )

    """

    Model training

    """

    # Stellargraph object
    my_stellar_graph = StellarGraph.StellarGraph(
        {"siRNA": sirna_pd, "mRNA": mrna_pd, "interaction": interaction_pd},
        edges=all_my_edges,
        source_column="source",
        target_column="target",
    )

    # Generator
    generator = HinSAGENodeGenerator(
        my_stellar_graph,
        params["batch_size"],
        params["hop_samples"],
        head_node_type="interaction",
    )

    hinsage_model = HinSAGE(
        layer_sizes=params["hinsage_layer_sizes"],
        generator=generator,
        bias=True,
        dropout=params["dropout"],
    )

    x_inp, x_out = hinsage_model.in_out_tensors()

    # Predictor
    prediction = layers.Dense(units=1)(x_out)

    model = Model(inputs=x_inp, outputs=prediction)
    model.compile(optimizer=optimizers.Adam(lr=params["lr"]), loss=params["loss"])

    # train flow
    train_interaction = pd.DataFrame(
        data_train["efficacy"].values,
        index=data_train["siRNA"] + "_" + data_train["mRNA"],
    )
    train_gen = generator.flow(train_interaction.index, train_interaction, shuffle=True)

    # dev flow
    dev_interaction = pd.DataFrame(
        data_dev["efficacy"].values, index=data_dev["siRNA"] + "_" + data_dev["mRNA"]
    )

    dev_gen = generator.flow(dev_interaction.index, dev_interaction)

    # model fit
    history = model.fit(
        train_gen,
        epochs=params["epochs"],
        validation_data=dev_gen,
        verbose=2,
        shuffle=False,
    )

    # Plot the training history
    history_plot = StellarGraph.utils.plot_history(history, return_figure=True)

    """

    Evaluate on the testset

    """

    # test flow
    test_interaction = pd.DataFrame(
        data_test["efficacy"].values, index=data_test["siRNA"] + "_" + data_test["mRNA"]
    )
    test_gen = generator.flow(test_interaction.index, test_interaction)

    # predict
    test = model.predict(test_gen)
    test = np.squeeze(test)

    """

    Calculate the metrics

    """

    # PCC
    pearson = scipy.stats.pearsonr(test_interaction.values.ravel(), test)
    score_PCC.append(pearson[0])
    print(pearson[0])

    # SPCC
    spearman = scipy.stats.spearmanr(test_interaction.values.ravel(), test)
    score_SPCC.append(spearman[0])
    print(spearman[0])

    # MSE
    mse_run = mean_squared_error(test_interaction.values.ravel(), test)
    score_mse.append(mse_run)
    print(mse_run)

    # AUC
    binary_pred = (test_interaction.values.ravel() > 0.7).astype(int)
    auc = roc_auc_score(binary_pred, test)
    score_auc.append(auc)
    print(auc)

    print(str(n) + " " + "finished!")


# Print the average value of metrics
print("Overall PCC score = ", np.mean(score_PCC))
print("Overall SPCC score = ", np.mean(score_SPCC))
print("Overall MSE score = ", np.mean(score_mse))
print("Overall AUC score = ", np.mean(score_auc))
# Out:
# 2025-10-29 13:19:52.360360: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 13:19:52.677157: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ashu/Documents/btp/siRNADiscovery-main/venv/lib/python3.8/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/26
# 31/31 - 13s - loss: 0.1030 - val_loss: 0.0397 - 13s/epoch - 410ms/step
# Epoch 2/26
# 31/31 - 8s - loss: 0.0416 - val_loss: 0.0365 - 8s/epoch - 263ms/step
# Epoch 3/26
# 31/31 - 8s - loss: 0.0393 - val_loss: 0.0353 - 8s/epoch - 248ms/step
# Epoch 4/26
# 31/31 - 7s - loss: 0.0371 - val_loss: 0.0342 - 7s/epoch - 242ms/step
# Epoch 5/26
# 31/31 - 8s - loss: 0.0353 - val_loss: 0.0333 - 8s/epoch - 242ms/step
# Epoch 6/26
# 31/31 - 8s - loss: 0.0330 - val_loss: 0.0307 - 8s/epoch - 245ms/step
# Epoch 7/26
# 31/31 - 8s - loss: 0.0305 - val_loss: 0.0275 - 8s/epoch - 251ms/step
# Epoch 8/26
# 31/31 - 8s - loss: 0.0275 - val_loss: 0.0272 - 8s/epoch - 245ms/step
# Epoch 9/26
# 31/31 - 8s - loss: 0.0241 - val_loss: 0.0236 - 8s/epoch - 248ms/step
# Epoch 10/26
# 31/31 - 7s - loss: 0.0231 - val_loss: 0.0247 - 7s/epoch - 240ms/step
# Epoch 11/26
# 31/31 - 7s - loss: 0.0219 - val_loss: 0.0208 - 7s/epoch - 241ms/step
# Epoch 12/26
# 31/31 - 7s - loss: 0.0213 - val_loss: 0.0238 - 7s/epoch - 240ms/step
# Epoch 13/26
# 31/31 - 7s - loss: 0.0203 - val_loss: 0.0215 - 7s/epoch - 240ms/step
# Epoch 14/26
# 31/31 - 8s - loss: 0.0193 - val_loss: 0.0195 - 8s/epoch - 242ms/step
# Epoch 15/26
# 31/31 - 7s - loss: 0.0180 - val_loss: 0.0202 - 7s/epoch - 237ms/step
# Epoch 16/26
# 31/31 - 7s - loss: 0.0176 - val_loss: 0.0191 - 7s/epoch - 239ms/step
# Epoch 17/26
# 31/31 - 8s - loss: 0.0176 - val_loss: 0.0207 - 8s/epoch - 247ms/step
# Epoch 18/26
# 31/31 - 7s - loss: 0.0170 - val_loss: 0.0192 - 7s/epoch - 239ms/step
# Epoch 19/26
# 31/31 - 7s - loss: 0.0162 - val_loss: 0.0204 - 7s/epoch - 237ms/step
# Epoch 20/26
# 31/31 - 7s - loss: 0.0162 - val_loss: 0.0191 - 7s/epoch - 240ms/step
# Epoch 21/26
# 31/31 - 7s - loss: 0.0157 - val_loss: 0.0198 - 7s/epoch - 242ms/step
# Epoch 22/26
# 31/31 - 7s - loss: 0.0157 - val_loss: 0.0190 - 7s/epoch - 241ms/step
# Epoch 23/26
# 31/31 - 8s - loss: 0.0150 - val_loss: 0.0183 - 8s/epoch - 274ms/step
# Epoch 24/26
# 31/31 - 8s - loss: 0.0150 - val_loss: 0.0197 - 8s/epoch - 259ms/step
# Epoch 25/26
# 31/31 - 8s - loss: 0.0144 - val_loss: 0.0189 - 8s/epoch - 251ms/step
# Epoch 26/26
# 31/31 - 8s - loss: 0.0144 - val_loss: 0.0189 - 8s/epoch - 271ms/step
# 7/7 [==============================] - 1s 120ms/step
# 0.7378273169300795
# 0.7450808423991369
# 0.02153470800427556
# 0.8470247321248062
# 0 finished!
# /home/ashu/Documents/btp/siRNADiscovery-main/venv/lib/python3.8/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/26
# 31/31 - 10s - loss: 0.0932 - val_loss: 0.0442 - 10s/epoch - 336ms/step
# Epoch 2/26
# 31/31 - 8s - loss: 0.0414 - val_loss: 0.0408 - 8s/epoch - 247ms/step
# Epoch 3/26
# 31/31 - 7s - loss: 0.0386 - val_loss: 0.0393 - 7s/epoch - 239ms/step
# Epoch 4/26
# 31/31 - 8s - loss: 0.0378 - val_loss: 0.0384 - 8s/epoch - 244ms/step
# Epoch 5/26
# 31/31 - 7s - loss: 0.0360 - val_loss: 0.0364 - 7s/epoch - 239ms/step
# Epoch 6/26
# 31/31 - 7s - loss: 0.0345 - val_loss: 0.0347 - 7s/epoch - 239ms/step
# Epoch 7/26
# 31/31 - 8s - loss: 0.0324 - val_loss: 0.0316 - 8s/epoch - 248ms/step
# Epoch 8/26
# 31/31 - 7s - loss: 0.0288 - val_loss: 0.0291 - 7s/epoch - 241ms/step
# Epoch 9/26
# 31/31 - 8s - loss: 0.0259 - val_loss: 0.0281 - 8s/epoch - 243ms/step
# Epoch 10/26
# 31/31 - 7s - loss: 0.0236 - val_loss: 0.0259 - 7s/epoch - 240ms/step
# Epoch 11/26
# 31/31 - 7s - loss: 0.0227 - val_loss: 0.0244 - 7s/epoch - 241ms/step
# Epoch 12/26
# 31/31 - 7s - loss: 0.0216 - val_loss: 0.0237 - 7s/epoch - 240ms/step
# Epoch 13/26
# 31/31 - 8s - loss: 0.0208 - val_loss: 0.0236 - 8s/epoch - 245ms/step
# Epoch 14/26
# 31/31 - 7s - loss: 0.0200 - val_loss: 0.0232 - 7s/epoch - 240ms/step
# Epoch 15/26
# 31/31 - 7s - loss: 0.0196 - val_loss: 0.0231 - 7s/epoch - 237ms/step
# Epoch 16/26
# 31/31 - 8s - loss: 0.0189 - val_loss: 0.0214 - 8s/epoch - 244ms/step
# Epoch 17/26
# 31/31 - 7s - loss: 0.0181 - val_loss: 0.0211 - 7s/epoch - 240ms/step
# Epoch 18/26
# 31/31 - 7s - loss: 0.0177 - val_loss: 0.0215 - 7s/epoch - 239ms/step
# Epoch 19/26
# 31/31 - 7s - loss: 0.0176 - val_loss: 0.0217 - 7s/epoch - 236ms/step
# Epoch 20/26
# 31/31 - 7s - loss: 0.0167 - val_loss: 0.0195 - 7s/epoch - 237ms/step
# Epoch 21/26
# 31/31 - 7s - loss: 0.0165 - val_loss: 0.0191 - 7s/epoch - 239ms/step
# Epoch 22/26
# 31/31 - 7s - loss: 0.0159 - val_loss: 0.0201 - 7s/epoch - 238ms/step
# Epoch 23/26
# 31/31 - 7s - loss: 0.0152 - val_loss: 0.0201 - 7s/epoch - 239ms/step
# Epoch 24/26
# 31/31 - 7s - loss: 0.0155 - val_loss: 0.0187 - 7s/epoch - 242ms/step
# Epoch 25/26
# 31/31 - 7s - loss: 0.0158 - val_loss: 0.0195 - 7s/epoch - 239ms/step
# Epoch 26/26
# 31/31 - 7s - loss: 0.0151 - val_loss: 0.0187 - 7s/epoch - 237ms/step
# 7/7 [==============================] - 1s 100ms/step
# 0.7395919479611085
# 0.7256366017154375
# 0.021365549489402374
# 0.8640717754991906
# 1 finished!
# /home/ashu/Documents/btp/siRNADiscovery-main/venv/lib/python3.8/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/26
# 31/31 - 9s - loss: 0.3605 - val_loss: 0.0754 - 9s/epoch - 303ms/step
# Epoch 2/26
# 31/31 - 8s - loss: 0.0490 - val_loss: 0.0422 - 8s/epoch - 245ms/step
# Epoch 3/26
# 31/31 - 7s - loss: 0.0412 - val_loss: 0.0407 - 7s/epoch - 240ms/step
# Epoch 4/26
# 31/31 - 7s - loss: 0.0397 - val_loss: 0.0392 - 7s/epoch - 241ms/step
# Epoch 5/26
# 31/31 - 7s - loss: 0.0383 - val_loss: 0.0383 - 7s/epoch - 240ms/step
# Epoch 6/26
# 31/31 - 7s - loss: 0.0372 - val_loss: 0.0369 - 7s/epoch - 242ms/step
# Epoch 7/26
# 31/31 - 7s - loss: 0.0364 - val_loss: 0.0355 - 7s/epoch - 239ms/step
# Epoch 8/26
# 31/31 - 8s - loss: 0.0350 - val_loss: 0.0344 - 8s/epoch - 271ms/step
# Epoch 9/26
# 31/31 - 9s - loss: 0.0341 - val_loss: 0.0343 - 9s/epoch - 282ms/step
# Epoch 10/26
# 31/31 - 8s - loss: 0.0312 - val_loss: 0.0330 - 8s/epoch - 253ms/step
# Epoch 11/26
# 31/31 - 8s - loss: 0.0296 - val_loss: 0.0296 - 8s/epoch - 264ms/step
# Epoch 12/26
# 31/31 - 9s - loss: 0.0278 - val_loss: 0.0285 - 9s/epoch - 281ms/step
# Epoch 13/26
# 31/31 - 9s - loss: 0.0263 - val_loss: 0.0264 - 9s/epoch - 281ms/step
# Epoch 14/26
# 31/31 - 8s - loss: 0.0245 - val_loss: 0.0249 - 8s/epoch - 256ms/step
# Epoch 15/26
# 31/31 - 8s - loss: 0.0230 - val_loss: 0.0251 - 8s/epoch - 258ms/step
# Epoch 16/26
# 31/31 - 7s - loss: 0.0225 - val_loss: 0.0233 - 7s/epoch - 239ms/step
# Epoch 17/26
# 31/31 - 7s - loss: 0.0221 - val_loss: 0.0256 - 7s/epoch - 238ms/step
# Epoch 18/26
# 31/31 - 7s - loss: 0.0216 - val_loss: 0.0232 - 7s/epoch - 241ms/step
# Epoch 19/26
# 31/31 - 7s - loss: 0.0209 - val_loss: 0.0214 - 7s/epoch - 235ms/step
# Epoch 20/26
# 31/31 - 7s - loss: 0.0201 - val_loss: 0.0219 - 7s/epoch - 240ms/step
# Epoch 21/26
# 31/31 - 7s - loss: 0.0193 - val_loss: 0.0211 - 7s/epoch - 240ms/step
# Epoch 22/26
# 31/31 - 7s - loss: 0.0191 - val_loss: 0.0222 - 7s/epoch - 241ms/step
# Epoch 23/26
# 31/31 - 7s - loss: 0.0182 - val_loss: 0.0207 - 7s/epoch - 240ms/step
# Epoch 24/26
# 31/31 - 7s - loss: 0.0177 - val_loss: 0.0204 - 7s/epoch - 238ms/step
# Epoch 25/26
# 31/31 - 7s - loss: 0.0176 - val_loss: 0.0201 - 7s/epoch - 241ms/step
# Epoch 26/26
# 31/31 - 7s - loss: 0.0171 - val_loss: 0.0202 - 7s/epoch - 241ms/step
# 7/7 [==============================] - 1s 100ms/step
# 0.7608784822542745
# 0.7570773457838694
# 0.019422463518266257
# 0.8823529411764706
# 2 finished!
# Overall PCC score =  0.7460992490484873
# Overall SPCC score =  0.7425982632994813
# Overall MSE score =  0.020774240337314728
# Overall AUC score =  0.8644831496001558

# %% [markdown]
# # 1. Number of Nodes, Edges, and Features

# %%
# Add this code after the my_stellar_graph object is created

print(my_stellar_graph.info())

# To get more specific numbers, you can add the following:

num_sirna_nodes = sirna_pd.shape[0]
num_mrna_nodes = mrna_pd.shape[0]
num_interaction_nodes = interaction_pd.shape[0]
total_nodes = num_sirna_nodes + num_mrna_nodes + num_interaction_nodes
num_edges = len(all_my_edges)

print(f"Number of siRNA nodes: {num_sirna_nodes}")
print(f"Number of mRNA nodes: {num_mrna_nodes}")
print(f"Number of interaction nodes: {num_interaction_nodes}")
print(f"Total number of nodes: {total_nodes}")
print(f"Total number of edges: {num_edges}")
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 5673, Edges: 5632
#
#  Node types:
#   siRNA: [2816]
#     Features: float32 vector, length 1513
#     Edge types: siRNA-default->interaction
#   interaction: [2816]
#     Features: float32 vector, length 197
#     Edge types: interaction-default->mRNA, interaction-default->siRNA
#   mRNA: [41]
#     Features: float32 vector, length 39126
#     Edge types: mRNA-default->interaction
#
#  Edge types:
#     interaction-default->siRNA: [2816]
#         Weights: all 1 (default)
#         Features: none
#     interaction-default->mRNA: [2816]
#         Weights: all 1 (default)
#         Features: none
# Number of siRNA nodes: 2816
# Number of mRNA nodes: 41
# Number of interaction nodes: 2816
# Total number of nodes: 5673
# Total number of edges: 5632

# %% [markdown]
# # 2. Max mRNA length

# %%
# Code to find the max mRNA length
max_mrna_length = data["mRNA_seq"].str.len().max()
print(f"Maximum mRNA length: {max_mrna_length}")
# Out:
# Maximum mRNA length: 9756

# %% [markdown]
# # 3. Number of Features for siRNA, mRNA, and Interaction Nodes

# %%
# Get the number of features for each node type
sirna_features = sirna_pd.shape[1]
mrna_features = mrna_pd.shape[1]
interaction_features = interaction_pd.shape[1]
total_features = sirna_features + mrna_features + interaction_features

print(f"Number of features for siRNA nodes: {sirna_features}")
print(f"Number of features for mRNA nodes: {mrna_features}")
print(f"Number of features for Interaction nodes: {interaction_features}")
print(f"Total number of features in the graph: {total_features}")
# Out:
# Number of features for siRNA nodes: 1513
# Number of features for mRNA nodes: 39126
# Number of features for Interaction nodes: 197
# Total number of features in the graph: 40836

# %% [markdown]
# # 4. Running the Code with Different Batch Sizes (10 to 30)

# %%
# --- Batchwise Training Loop with PCC, SPCC, MSE, and AUC ---



results = []  # to store metrics for each batch size

for batch_size in range(10, 17):
    print(f"\n--- TRAINING WITH BATCH SIZE: {batch_size} ---\n")

    # Generator - re-initialize with the new batch size
    generator = HinSAGENodeGenerator(
        my_stellar_graph,
        batch_size,  # Use the batch_size from the loop
        params["hop_samples"],
        head_node_type="interaction",
    )

    hinsage_model = HinSAGE(
        layer_sizes=params["hinsage_layer_sizes"],
        generator=generator,
        bias=True,
        dropout=params["dropout"],
    )

    x_inp, x_out = hinsage_model.in_out_tensors()

    # Predictor
    prediction = layers.Dense(units=1, activation="sigmoid")(x_out)

    model = Model(inputs=x_inp, outputs=prediction)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=params["lr"]), loss=params["loss"]
    )

    # train flow
    train_gen = generator.flow(train_interaction.index, train_interaction, shuffle=True)

    # dev flow
    dev_gen = generator.flow(dev_interaction.index, dev_interaction)

    # model fit
    history = model.fit(
        train_gen,
        epochs=params["epochs"],
        validation_data=dev_gen,
        verbose=0,  # to reduce excessive logs
        shuffle=False,
    )

    # test flow
    test_gen = generator.flow(test_interaction.index, test_interaction)

    # predict
    test_pred = model.predict(test_gen)
    test_pred = np.squeeze(test_pred)

    y_true = test_interaction.values.ravel()

    # --- Metrics ---
    # PCC (Pearson Correlation Coefficient)
    pcc, _ = pearsonr(y_true, test_pred)

    # SPCC (Spearman Rank Correlation Coefficient)
    spcc, _ = spearmanr(y_true, test_pred)

    # MSE (Mean Squared Error)
    mse = mean_squared_error(y_true, test_pred)

    # AUC (Area Under ROC Curve)
    try:
        auc = roc_auc_score(y_true, test_pred)
    except ValueError:
        auc = None  # In case only one class present

    print(
        f"Batch Size {batch_size} - PCC: {pcc:.4f}, SPCC: {spcc:.4f}, MSE: {mse:.6f}, AUC: {auc}"
    )

    # Save metrics
    results.append(
        {"batch_size": batch_size, "PCC": pcc, "SPCC": spcc, "MSE": mse, "AUC": auc}
    )

# Convert results to DataFrame for summary
results_df = pd.DataFrame(results)
print("\n=== Summary of Results ===")
print(results_df)
# Out:
# --- TRAINING WITH BATCH SIZE: 10 ---
